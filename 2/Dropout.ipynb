# %% [markdown]
# # Dropout
# Dropout [1] is a technique for regularizing neural networks by randomly setting some features to zero during the forward pass. In this exercise you will implement a dropout layer and modify your fully-connected network to optionally use dropout.
#
# [1] Geoffrey E. Hinton et al, "Improving neural networks by preventing co-adaptation of feature detectors", arXiv 2012

# %%
# As usual, a bit of setup
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k, v in data.items():
    print('%s: ' % k, v.shape)
# Out:
# X_val:  (1000, 3, 32, 32)
# y_train:  (49000,)
# X_train:  (49000, 3, 32, 32)
# y_val:  (1000,)
# X_test:  (1000, 3, 32, 32)
# y_test:  (1000,)

# %% [markdown]
# # Dropout forward pass
# In the file `cs231n/layers.py`, implement the forward pass for dropout. Since dropout behaves differently during training and testing, make sure to implement the operation for both modes.
#
# Once you have done so, run the cell below to test your implementation.

# %%
np.random.seed(231)
x = np.random.randn(500, 500) + 10

for p in [0.3, 0.6, 0.75]:
    out, _ = dropout_forward(x, {'mode': 'train', 'p': p})
    out_test, _ = dropout_forward(x, {'mode': 'test', 'p': p})

    print('Running tests with p = ', p)
    print('Mean of input: ', x.mean())
    print('Mean of train-time output: ', out.mean())
    print('Mean of test-time output: ', out_test.mean())
    print('Fraction of train-time output set to zero: ', (out == 0).mean())
    print('Fraction of test-time output set to zero: ', (out_test == 0).mean())
    print()
# Out:
# Running tests with p =  0.3
# Mean of input:  10.0002078785
# Mean of train-time output:  9.98526577052
# Mean of test-time output:  10.0002078785
# Fraction of train-time output set to zero:  0.300876
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.6
# Mean of input:  10.0002078785
# Mean of train-time output:  10.035153558
# Mean of test-time output:  10.0002078785
# Fraction of train-time output set to zero:  0.598632
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.75
# Mean of input:  10.0002078785
# Mean of train-time output:  10.0216257491
# Mean of test-time output:  10.0002078785
# Fraction of train-time output set to zero:  0.749504
# Fraction of test-time output set to zero:  0.0

# %% [markdown]
# # Dropout backward pass
# In the file `cs231n/layers.py`, implement the backward pass for dropout. After doing so, run the following cell to numerically gradient-check your implementation.

# %%
np.random.seed(231)
x = np.random.randn(10, 10) + 10
dout = np.random.randn(*x.shape)

dropout_param = {'mode': 'train', 'p': 0.8, 'seed': 123}
out, cache = dropout_forward(x, dropout_param)
dx = dropout_backward(dout, cache)
dx_num = eval_numerical_gradient_array(lambda xx: dropout_forward(xx, dropout_param)[0], x, dout)

print('dx relative error: ', rel_error(dx, dx_num))
# Out:
# dx relative error:  1.89290835574e-11

# %% [markdown]
# # Fully-connected nets with Dropout
# In the file `cs231n/classifiers/fc_net.py`, modify your implementation to use dropout. Specificially, if the constructor the the net receives a nonzero value for the `dropout` parameter, then the net should add dropout immediately after every ReLU nonlinearity. After doing so, run the following to numerically gradient-check your implementation.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for dropout in [0, 0.25, 0.5]:
    print('Running check with dropout = ', dropout)
    model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            weight_scale=5e-2, dtype=np.float64,
                            dropout=dropout, seed=123)

    loss, grads = model.loss(X, y)
    print('Initial loss: ', loss)

    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
    print()
# Out:
# Running check with dropout =  0
# Initial loss:  2.30047908977
# W1 relative error: 1.48e-07
# W2 relative error: 2.21e-05
# W3 relative error: 3.53e-07
# b1 relative error: 5.38e-09
# b2 relative error: 2.09e-09
# b3 relative error: 5.80e-11
#
# Running check with dropout =  0.25
# Initial loss:  2.30486921512
# W1 relative error: 2.47e-07
# W2 relative error: 1.69e-06
# W3 relative error: 8.70e-07
# b1 relative error: 7.84e-09
# b2 relative error: 6.85e-09
# b3 relative error: 1.13e-10
#
# Running check with dropout =  0.5
# Initial loss:  2.31013690872
# W1 relative error: 2.57e-08
# W2 relative error: 1.49e-08
# W3 relative error: 4.49e-08
# b1 relative error: 1.35e-09
# b2 relative error: 1.91e-09
# b3 relative error: 9.51e-11

# %% [markdown]
# # Regularization experiment
# As an experiment, we will train a pair of two-layer networks on 500 training examples: one will use no dropout, and one will use a dropout probability of 0.75. We will then visualize the training and validation accuracies of the two networks over time.

# %%
# Train two identical nets, one with dropout and one without
np.random.seed(231)
num_train = 500
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}
dropout_choices = [0, 0.25, 0.5, 0.75]
for dropout in dropout_choices:
    model = FullyConnectedNet([500], dropout=dropout)
    print(dropout)

    solver = Solver(model, small_data,
                  num_epochs=50, batch_size=100,
                  update_rule='adam',
                  optim_config={
                    'learning_rate': 5e-4,
                  },
                  verbose=True, print_every=100)
    solver.train()
    solvers[dropout] = solver
# Out:
# 0
# (Iteration 1 / 250) loss: 7.856644
# (Epoch 0 / 50) train acc: 0.274000; val_acc: 0.192000
# (Epoch 1 / 50) train acc: 0.410000; val_acc: 0.263000
# (Epoch 2 / 50) train acc: 0.518000; val_acc: 0.269000
# (Epoch 3 / 50) train acc: 0.550000; val_acc: 0.248000
# (Epoch 4 / 50) train acc: 0.684000; val_acc: 0.297000
# (Epoch 5 / 50) train acc: 0.758000; val_acc: 0.292000
# (Epoch 6 / 50) train acc: 0.782000; val_acc: 0.266000
# (Epoch 7 / 50) train acc: 0.860000; val_acc: 0.240000
# (Epoch 8 / 50) train acc: 0.864000; val_acc: 0.285000
# (Epoch 9 / 50) train acc: 0.898000; val_acc: 0.279000
# (Epoch 10 / 50) train acc: 0.908000; val_acc: 0.269000
# (Epoch 11 / 50) train acc: 0.948000; val_acc: 0.294000
# (Epoch 12 / 50) train acc: 0.960000; val_acc: 0.286000
# (Epoch 13 / 50) train acc: 0.954000; val_acc: 0.283000
# (Epoch 14 / 50) train acc: 0.954000; val_acc: 0.267000
# (Epoch 15 / 50) train acc: 0.950000; val_acc: 0.281000
# (Epoch 16 / 50) train acc: 0.940000; val_acc: 0.269000
# (Epoch 17 / 50) train acc: 0.950000; val_acc: 0.293000
# (Epoch 18 / 50) train acc: 0.956000; val_acc: 0.295000
# (Epoch 19 / 50) train acc: 0.964000; val_acc: 0.278000
# (Epoch 20 / 50) train acc: 0.968000; val_acc: 0.297000
# (Iteration 101 / 250) loss: 0.092255
# (Epoch 21 / 50) train acc: 0.980000; val_acc: 0.309000
# (Epoch 22 / 50) train acc: 0.986000; val_acc: 0.288000
# (Epoch 23 / 50) train acc: 0.968000; val_acc: 0.288000
# (Epoch 24 / 50) train acc: 0.994000; val_acc: 0.278000
# (Epoch 25 / 50) train acc: 0.982000; val_acc: 0.281000
# (Epoch 26 / 50) train acc: 0.992000; val_acc: 0.303000
# (Epoch 27 / 50) train acc: 0.994000; val_acc: 0.304000
# (Epoch 28 / 50) train acc: 0.978000; val_acc: 0.292000
# (Epoch 29 / 50) train acc: 0.982000; val_acc: 0.300000
# (Epoch 30 / 50) train acc: 0.994000; val_acc: 0.298000
# (Epoch 31 / 50) train acc: 0.994000; val_acc: 0.286000
# (Epoch 32 / 50) train acc: 0.982000; val_acc: 0.300000
# (Epoch 33 / 50) train acc: 0.966000; val_acc: 0.278000
# (Epoch 34 / 50) train acc: 0.980000; val_acc: 0.288000
# (Epoch 35 / 50) train acc: 0.992000; val_acc: 0.306000
# (Epoch 36 / 50) train acc: 0.984000; val_acc: 0.312000
# (Epoch 37 / 50) train acc: 0.988000; val_acc: 0.299000
# (Epoch 38 / 50) train acc: 0.992000; val_acc: 0.286000
# (Epoch 39 / 50) train acc: 0.988000; val_acc: 0.286000
# (Epoch 40 / 50) train acc: 0.978000; val_acc: 0.273000
# (Iteration 201 / 250) loss: 0.243994
# (Epoch 41 / 50) train acc: 0.994000; val_acc: 0.290000
# (Epoch 42 / 50) train acc: 0.998000; val_acc: 0.285000
# (Epoch 43 / 50) train acc: 0.994000; val_acc: 0.279000
# (Epoch 44 / 50) train acc: 0.990000; val_acc: 0.283000
# (Epoch 45 / 50) train acc: 0.994000; val_acc: 0.277000
# (Epoch 46 / 50) train acc: 0.998000; val_acc: 0.283000
# (Epoch 47 / 50) train acc: 0.998000; val_acc: 0.279000
# (Epoch 48 / 50) train acc: 1.000000; val_acc: 0.278000
# (Epoch 49 / 50) train acc: 0.996000; val_acc: 0.282000
# (Epoch 50 / 50) train acc: 0.998000; val_acc: 0.283000
# 0.25
# (Iteration 1 / 250) loss: 10.044813
# (Epoch 0 / 50) train acc: 0.258000; val_acc: 0.202000
# (Epoch 1 / 50) train acc: 0.444000; val_acc: 0.256000
# (Epoch 2 / 50) train acc: 0.536000; val_acc: 0.242000
# (Epoch 3 / 50) train acc: 0.600000; val_acc: 0.280000
# (Epoch 4 / 50) train acc: 0.654000; val_acc: 0.252000
# (Epoch 5 / 50) train acc: 0.698000; val_acc: 0.271000
# (Epoch 6 / 50) train acc: 0.764000; val_acc: 0.269000
# (Epoch 7 / 50) train acc: 0.794000; val_acc: 0.284000
# (Epoch 8 / 50) train acc: 0.832000; val_acc: 0.312000
# (Epoch 9 / 50) train acc: 0.886000; val_acc: 0.294000
# (Epoch 10 / 50) train acc: 0.896000; val_acc: 0.266000
# (Epoch 11 / 50) train acc: 0.912000; val_acc: 0.301000
# (Epoch 12 / 50) train acc: 0.914000; val_acc: 0.289000
# (Epoch 13 / 50) train acc: 0.922000; val_acc: 0.267000
# (Epoch 14 / 50) train acc: 0.964000; val_acc: 0.275000
# (Epoch 15 / 50) train acc: 0.944000; val_acc: 0.275000
# (Epoch 16 / 50) train acc: 0.956000; val_acc: 0.296000
# (Epoch 17 / 50) train acc: 0.948000; val_acc: 0.303000
# (Epoch 18 / 50) train acc: 0.982000; val_acc: 0.277000
# (Epoch 19 / 50) train acc: 0.986000; val_acc: 0.287000
# (Epoch 20 / 50) train acc: 0.970000; val_acc: 0.300000
# (Iteration 101 / 250) loss: 0.856983
# (Epoch 21 / 50) train acc: 0.982000; val_acc: 0.289000
# (Epoch 22 / 50) train acc: 0.982000; val_acc: 0.290000
# (Epoch 23 / 50) train acc: 0.984000; val_acc: 0.295000
# (Epoch 24 / 50) train acc: 0.986000; val_acc: 0.284000
# (Epoch 25 / 50) train acc: 0.988000; val_acc: 0.299000
# (Epoch 26 / 50) train acc: 0.984000; val_acc: 0.307000
# (Epoch 27 / 50) train acc: 0.978000; val_acc: 0.300000
# (Epoch 28 / 50) train acc: 0.960000; val_acc: 0.278000
# (Epoch 29 / 50) train acc: 0.972000; val_acc: 0.293000
# (Epoch 30 / 50) train acc: 0.980000; val_acc: 0.288000
# (Epoch 31 / 50) train acc: 0.986000; val_acc: 0.289000
# (Epoch 32 / 50) train acc: 0.990000; val_acc: 0.283000
# (Epoch 33 / 50) train acc: 0.986000; val_acc: 0.300000
# (Epoch 34 / 50) train acc: 0.992000; val_acc: 0.305000
# (Epoch 35 / 50) train acc: 0.978000; val_acc: 0.297000
# (Epoch 36 / 50) train acc: 0.986000; val_acc: 0.294000
# (Epoch 37 / 50) train acc: 0.976000; val_acc: 0.282000
# (Epoch 38 / 50) train acc: 0.990000; val_acc: 0.294000
# (Epoch 39 / 50) train acc: 0.984000; val_acc: 0.285000
# (Epoch 40 / 50) train acc: 0.994000; val_acc: 0.302000
# (Iteration 201 / 250) loss: 0.144449
# (Epoch 41 / 50) train acc: 0.986000; val_acc: 0.316000
# (Epoch 42 / 50) train acc: 0.984000; val_acc: 0.311000
# (Epoch 43 / 50) train acc: 0.996000; val_acc: 0.310000
# (Epoch 44 / 50) train acc: 0.992000; val_acc: 0.296000
# (Epoch 45 / 50) train acc: 0.998000; val_acc: 0.310000
# (Epoch 46 / 50) train acc: 0.996000; val_acc: 0.303000
# (Epoch 47 / 50) train acc: 0.996000; val_acc: 0.298000
# (Epoch 48 / 50) train acc: 0.994000; val_acc: 0.300000
# (Epoch 49 / 50) train acc: 0.998000; val_acc: 0.295000
# (Epoch 50 / 50) train acc: 1.000000; val_acc: 0.298000
# 0.5
# (Iteration 1 / 250) loss: 10.189969
# (Epoch 0 / 50) train acc: 0.226000; val_acc: 0.162000
# (Epoch 1 / 50) train acc: 0.398000; val_acc: 0.244000
# (Epoch 2 / 50) train acc: 0.502000; val_acc: 0.266000
# (Epoch 3 / 50) train acc: 0.518000; val_acc: 0.274000
# (Epoch 4 / 50) train acc: 0.620000; val_acc: 0.282000
# (Epoch 5 / 50) train acc: 0.682000; val_acc: 0.256000
# (Epoch 6 / 50) train acc: 0.756000; val_acc: 0.267000
# (Epoch 7 / 50) train acc: 0.766000; val_acc: 0.297000
# (Epoch 8 / 50) train acc: 0.822000; val_acc: 0.312000
# (Epoch 9 / 50) train acc: 0.854000; val_acc: 0.328000
# (Epoch 10 / 50) train acc: 0.826000; val_acc: 0.332000
# (Epoch 11 / 50) train acc: 0.862000; val_acc: 0.308000
# (Epoch 12 / 50) train acc: 0.906000; val_acc: 0.281000
# (Epoch 13 / 50) train acc: 0.920000; val_acc: 0.291000
# (Epoch 14 / 50) train acc: 0.912000; val_acc: 0.321000
# (Epoch 15 / 50) train acc: 0.922000; val_acc: 0.299000
# (Epoch 16 / 50) train acc: 0.958000; val_acc: 0.323000
# (Epoch 17 / 50) train acc: 0.906000; val_acc: 0.319000
# (Epoch 18 / 50) train acc: 0.902000; val_acc: 0.279000
# (Epoch 19 / 50) train acc: 0.940000; val_acc: 0.301000
# (Epoch 20 / 50) train acc: 0.898000; val_acc: 0.322000
# (Iteration 101 / 250) loss: 2.229864
# (Epoch 21 / 50) train acc: 0.956000; val_acc: 0.309000
# (Epoch 22 / 50) train acc: 0.938000; val_acc: 0.297000
# (Epoch 23 / 50) train acc: 0.968000; val_acc: 0.319000
# (Epoch 24 / 50) train acc: 0.960000; val_acc: 0.308000
# (Epoch 25 / 50) train acc: 0.968000; val_acc: 0.311000
# (Epoch 26 / 50) train acc: 0.954000; val_acc: 0.321000
# (Epoch 27 / 50) train acc: 0.958000; val_acc: 0.320000
# (Epoch 28 / 50) train acc: 0.970000; val_acc: 0.311000
# (Epoch 29 / 50) train acc: 0.962000; val_acc: 0.310000
# (Epoch 30 / 50) train acc: 0.980000; val_acc: 0.302000
# (Epoch 31 / 50) train acc: 0.978000; val_acc: 0.313000
# (Epoch 32 / 50) train acc: 0.986000; val_acc: 0.313000
# (Epoch 33 / 50) train acc: 0.988000; val_acc: 0.333000
# (Epoch 34 / 50) train acc: 0.982000; val_acc: 0.315000
# (Epoch 35 / 50) train acc: 0.988000; val_acc: 0.314000
# (Epoch 36 / 50) train acc: 0.966000; val_acc: 0.295000
# (Epoch 37 / 50) train acc: 0.992000; val_acc: 0.306000
# (Epoch 38 / 50) train acc: 0.988000; val_acc: 0.292000
# (Epoch 39 / 50) train acc: 0.992000; val_acc: 0.317000
# (Epoch 40 / 50) train acc: 0.982000; val_acc: 0.311000
# (Iteration 201 / 250) loss: 0.630373
# (Epoch 41 / 50) train acc: 0.990000; val_acc: 0.305000
# (Epoch 42 / 50) train acc: 0.988000; val_acc: 0.314000
# (Epoch 43 / 50) train acc: 0.994000; val_acc: 0.299000
# (Epoch 44 / 50) train acc: 0.994000; val_acc: 0.302000
# (Epoch 45 / 50) train acc: 0.990000; val_acc: 0.325000
# (Epoch 46 / 50) train acc: 0.998000; val_acc: 0.323000
# (Epoch 47 / 50) train acc: 0.990000; val_acc: 0.303000
# (Epoch 48 / 50) train acc: 0.996000; val_acc: 0.299000
# (Epoch 49 / 50) train acc: 1.000000; val_acc: 0.301000
# (Epoch 50 / 50) train acc: 0.988000; val_acc: 0.294000
# 0.75
# (Iteration 1 / 250) loss: 17.189080
# (Epoch 0 / 50) train acc: 0.222000; val_acc: 0.174000
# (Epoch 1 / 50) train acc: 0.382000; val_acc: 0.254000
# (Epoch 2 / 50) train acc: 0.440000; val_acc: 0.306000
# (Epoch 3 / 50) train acc: 0.482000; val_acc: 0.300000
# (Epoch 4 / 50) train acc: 0.602000; val_acc: 0.294000
# (Epoch 5 / 50) train acc: 0.542000; val_acc: 0.294000
# (Epoch 6 / 50) train acc: 0.618000; val_acc: 0.311000
# (Epoch 7 / 50) train acc: 0.654000; val_acc: 0.270000
# (Epoch 8 / 50) train acc: 0.710000; val_acc: 0.279000
# (Epoch 9 / 50) train acc: 0.742000; val_acc: 0.304000
# (Epoch 10 / 50) train acc: 0.758000; val_acc: 0.299000
# (Epoch 11 / 50) train acc: 0.766000; val_acc: 0.323000
# (Epoch 12 / 50) train acc: 0.798000; val_acc: 0.326000
# (Epoch 13 / 50) train acc: 0.794000; val_acc: 0.290000
# (Epoch 14 / 50) train acc: 0.816000; val_acc: 0.321000
# (Epoch 15 / 50) train acc: 0.846000; val_acc: 0.296000
# (Epoch 16 / 50) train acc: 0.868000; val_acc: 0.325000
# (Epoch 17 / 50) train acc: 0.878000; val_acc: 0.313000
# (Epoch 18 / 50) train acc: 0.874000; val_acc: 0.320000
# (Epoch 19 / 50) train acc: 0.900000; val_acc: 0.329000
# (Epoch 20 / 50) train acc: 0.908000; val_acc: 0.326000
# (Iteration 101 / 250) loss: 4.582299
# (Epoch 21 / 50) train acc: 0.924000; val_acc: 0.342000
# (Epoch 22 / 50) train acc: 0.916000; val_acc: 0.326000
# (Epoch 23 / 50) train acc: 0.916000; val_acc: 0.322000
# (Epoch 24 / 50) train acc: 0.902000; val_acc: 0.314000
# (Epoch 25 / 50) train acc: 0.928000; val_acc: 0.331000
# (Epoch 26 / 50) train acc: 0.930000; val_acc: 0.326000
# (Epoch 27 / 50) train acc: 0.946000; val_acc: 0.308000
# (Epoch 28 / 50) train acc: 0.934000; val_acc: 0.315000
# (Epoch 29 / 50) train acc: 0.930000; val_acc: 0.313000
# (Epoch 30 / 50) train acc: 0.948000; val_acc: 0.315000
# (Epoch 31 / 50) train acc: 0.938000; val_acc: 0.306000
# (Epoch 32 / 50) train acc: 0.952000; val_acc: 0.306000
# (Epoch 33 / 50) train acc: 0.970000; val_acc: 0.309000
# (Epoch 34 / 50) train acc: 0.966000; val_acc: 0.314000
# (Epoch 35 / 50) train acc: 0.968000; val_acc: 0.324000
# (Epoch 36 / 50) train acc: 0.968000; val_acc: 0.306000
# (Epoch 37 / 50) train acc: 0.960000; val_acc: 0.307000
# (Epoch 38 / 50) train acc: 0.954000; val_acc: 0.305000
# (Epoch 39 / 50) train acc: 0.962000; val_acc: 0.311000
# (Epoch 40 / 50) train acc: 0.952000; val_acc: 0.310000
# (Iteration 201 / 250) loss: 2.648455
# (Epoch 41 / 50) train acc: 0.954000; val_acc: 0.315000
# (Epoch 42 / 50) train acc: 0.944000; val_acc: 0.325000
# (Epoch 43 / 50) train acc: 0.970000; val_acc: 0.316000
# (Epoch 44 / 50) train acc: 0.964000; val_acc: 0.315000
# (Epoch 45 / 50) train acc: 0.954000; val_acc: 0.312000
# (Epoch 46 / 50) train acc: 0.958000; val_acc: 0.339000
# (Epoch 47 / 50) train acc: 0.958000; val_acc: 0.324000
# (Epoch 48 / 50) train acc: 0.972000; val_acc: 0.315000
# (Epoch 49 / 50) train acc: 0.970000; val_acc: 0.299000
# (Epoch 50 / 50) train acc: 0.966000; val_acc: 0.303000

# %%
# Plot train and validation accuracies of the two models

train_accs = []
val_accs = []
for dropout in dropout_choices:
    solver = solvers[dropout]
    train_accs.append(solver.train_acc_history[-1])
    val_accs.append(solver.val_acc_history[-1])

plt.subplot(3, 1, 1)
for dropout in dropout_choices:
    plt.plot(solvers[dropout].train_acc_history, 'o-', label='%.2f dropout' % dropout)
plt.title('Train accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')
  
plt.subplot(3, 1, 2)
for dropout in dropout_choices:
    plt.plot(solvers[dropout].val_acc_history, 'o-', label='%.2f dropout' % dropout)
plt.title('Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# # Question
# Explain what you see in this experiment. What does it suggest about dropout?

# %% [markdown]
# # Answer
